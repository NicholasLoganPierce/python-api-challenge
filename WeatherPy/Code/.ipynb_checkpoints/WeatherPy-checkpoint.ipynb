# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

#Import API Key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create The URL for One City
base_url = "http://api.openweathermap.org/data/2.5/weather?"
url = base_url + "appid=" + api_key + "&q=" + city + "&units=imperial"
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Look at The JSON Output for One City
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.79,
#         "lon": -161.76
#     },
#     "dt": 1577382720,
#     "id": 5880568,
#     "main": {
#         "feels_like": -26.86,
#         "humidity": 83,
#         "pressure": 1014,
#         "temp": -16.1,
#         "temp_max": -9.4,
#         "temp_min": -25.6
#     },
#     "name": "Bethel",
#     "sys": {
#         "country": "US",
#         "id": 7640,
#         "sunrise": 1577390311,
#         "sunset": 1577410593,
#         "type": 1
#     },
#     "timezone": -32400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 6.93
#     }
# }

# %%
# Create Lists for Dataframe
city_df = []
cloudiness = []
dates = []
humidity = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# Set Initial Counts
count_one = 0
set_one = 1

# For Loop to Extract DataFrame Contents
for city in cities:
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    url = base_url + "appid=" + api_key + "&q=" + city + "&units=imperial"
    try:
        response = requests.get(url).json()
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_df.append(city)
        else:
            count_one += 1
            city_df.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | vilyuysk
# Processing Record 4 of Set 1 | saint-francois
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | longyearbyen
# City not found. Skipping...
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | mehran
# Processing Record 14 of Set 1 | yatou
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | japura
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | bibiani
# Processing Record 21 of Set 1 | arraial do cabo
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a Dictionary to Set Up The Architecture of The DataFrame
weather_dict = {
    "City":city_df,
    "Cloudiness":cloudiness,
    "Country":countries,
    "Date":dates,
    "Humidity":humidity,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
# Create The DataFrame, Show The Counts
weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          555
# Cloudiness    555
# Country       555
# Date          555
# Humidity      555
# Lat           555
# Lng           555
# Max Temp      555
# Wind Speed    555
# dtype: int64

# %%
#Preview The DataFrame
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         rikitea         100      PF  1577382732        89 -23.12 -134.97
# 1         ushuaia          40      AR  1577382732        69 -54.81  -68.31
# 2        vilyuysk          28      RU  1577382732        96  63.75  121.63
# 3  saint-francois          90      FR  1577382732        76  46.42    3.91
# 4         mataura         100      NZ  1577382732        93 -46.19  168.86
#
#    Max Temp  Wind Speed
# 0     73.67       11.54
# 1     60.80       18.34
# 2    -41.48        6.73
# 3     50.00        8.05
# 4     50.00        1.99

# %%
# Export Data from The DataFrame to a CSV
weather_df.to_csv('weather_data.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"],edgecolors="black",facecolors="steelblue", alpha = .8)
plt.title("City Latitude vs. Max Temperature (12/25/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (linestyle="-",color="grey", alpha = .6)
plt.savefig("Plots/Lat_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],edgecolors="black",facecolors="steelblue", alpha = .8)
plt.title("City Latitude vs. Humidity (12/25/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (linestyle="-",color="grey", alpha = .6)
plt.savefig("Plots/Lat_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],edgecolors="black",facecolors="steelblue", alpha = .8)
plt.title("City Latitude vs. Cloudiness (12/25/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (linestyle="-",color="grey", alpha = .6)
plt.savefig("Plots/Lat_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],edgecolors="black",facecolors="steelblue", alpha = .8)
plt.title("City Latitude vs. Wind Speed (12/25/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (linestyle="-",color="grey", alpha = .6)
plt.savefig("Plots/Lat_WindSpeed.png")
plt.show()

# %%
print("                                     _______Three Observable Trends_______                          ")
print("1) Wind Speed, for the most part, seems to pretty constantly fall within the 0 to 10 mph range regardless of latitude. Cloudiness is similar in the sense that it doesn't seem dependent on latitude but dissimilar in that it doesn't fall within a constant range. The dispersion of cloudiness is pretty even although the heaviest concentrations are at the extremes (0%-100%).")
print("2) Generally it seems that the further North of the equator that you go, the more humid the atmosphere becomes. Humidity %  seems skewed to fall within the 60 to 100 % range across all latitudes, but at latitude 40 and above, the 80 to 100% humidi-ty range becomes heavily populated with dots on the sctter plot.")
print("3) Generally it seems that the further North of the equator that you go, the colder it becomes although going further South of the equator doesn't have as substantial of an effect on temperature. The max temp at latitude -60 is around 60 degrees   whereas the max temp at latitude 60 is around -40 degrees. All that said, the max temp at latitude -15 to latitude 20 (i.e. grouped around the equator) seems to fall pretty constantly within the 60 to 80 degree range.")
# Out:
#                                      _______Three Observable Trends_______
# 1) Wind Speed, for the most part, seems to pretty constantly fall within the 0 to 10 mph range regardless of latitude. Cloudiness is similar in the sense that it doesn't seem dependent on latitude but dissimilar in that it doesn't fall within a constant range. The dispersion of cloudiness is pretty even although the heaviest concentrations are at the extremes (0%-100%).
# 2) Generally it seems that the further North of the equator that you go, the more humid the atmosphere becomes. Humidity %  seems skewed to fall within the 60 to 100 % range across all latitudes, but at latitude 40 and above, the 80 to 100% humidi-ty range becomes heavily populated with dots on the sctter plot.
# ...
